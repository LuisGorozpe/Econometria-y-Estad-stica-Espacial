# %% [markdown]
# ---
# title: "Introduccion manejo de Datos Geoespaciales con R"
# author:
#   - name: Luis E. Ascencio G.
#     orcid: 0009-0009-1694-5993
#     email: luis.ascencio@cimat.mx
#     affiliation:
#       - name: CIMAT
#         city: Guanajuato
#         state: Guanajuato
#         url: https://www.cimat.mx
# abstract: >
#  En este NoteBook encontraras codigo para manejar Datos Geoespaciales con R
# keywords:
#   - R
#   - GeoEspacial
# license: "CC BY"
# copyright:
#   holder: Luis E. Ascencio G.
#   year: 2026
# citation:
#   container-title: CIMAT
#   volume: 1
#   issue: 1
#   doi: 000000/00000000
# funding: ".."
# format:
#   pdf:
#     documentclass: scrartcl
#     toc: true
#     number-sections: true
#     colorlinks: true
# ---

# %%
# Install the package if you haven't already
# install.packages("sf")
 install.packages("sf", dependencies = TRUE)
# Out:
# also installing the dependencies ‘Rcpp’, ‘geometries’, ‘rapidjsonr’, ‘sfheaders’, ‘systemfonts’, ‘logger’, ‘lazyeval’, ‘geojsonsf’, ‘crosstalk’, ‘leaflet.providers’, ‘svglite’, ‘xfun’, ‘goftest’, ‘tensor’, ‘stringdist’, ‘spacesXYZ’, ‘jsonify’, ‘XML’, ‘rex’, ‘leafem’, ‘leaflet’, ‘leafpop’, ‘png’, ‘satellite’, ‘servr’, ‘DBI’, ‘spatstat.data’, ‘spatstat.univar’, ‘spatstat.explore’, ‘spatstat.model’, ‘deldir’, ‘polyclip’, ‘spatstat.sparse’, ‘abind’, ‘cols4all’, ‘leafgl’, ‘leaflegend’, ‘leafsync’, ‘maptiles’, ‘tmaptools’, ‘classInt’, ‘s2’, ‘units’, ‘nanoarrow’, ‘covr’, ‘lwgeom’, ‘maps’, ‘mapview’, ‘microbenchmark’, ‘odbc’, ‘pbapply’, ‘pool’, ‘raster’, ‘RPostgres’, ‘RPostgreSQL’, ‘sp’, ‘spatstat’, ‘spatstat.geom’, ‘spatstat.random’, ‘spatstat.linnet’, ‘spatstat.utils’, ‘stars’, ‘terra’, ‘tmap’, ‘wk’
#
#
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘systemfonts’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘svglite’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘s2’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘units’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘RPostgres’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘RPostgreSQL’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘terra’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘raster’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘sf’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘leaflet’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘leafpop’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘satellite’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘maptiles’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘lwgeom’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘stars’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘leafem’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘leafgl’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘leaflegend’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘leafsync’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘tmaptools’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘mapview’ had non-zero exit status”
# Warning message in install.packages("sf", dependencies = TRUE):
# “installation of package ‘tmap’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Load the library
library(sf)
# Out:
# Error in library(sf): there is no package called ‘sf’
# Traceback:
#
# 1. library(sf)

# %% [markdown]
# https://klaothongchan.medium.com/getting-r-into-vscode-5d1c8bf7f745
